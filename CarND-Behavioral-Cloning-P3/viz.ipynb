# %%
import pickle
import matplotlib.pyplot as plt

# %%
m = loadModel('model.h5')
# Out:
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1253: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(strides=[2, 2], kernel_initializer="glorot_uniform", trainable=True, name="convolution2d_1", bias_constraint=None, kernel_constraint=None, filters=24, bias_regularizer=None, activation="relu", kernel_size=(5, 5), activity_regularizer=None, use_bias=True, data_format="channels_last", padding="valid", kernel_regularizer=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1253: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(strides=[2, 2], kernel_initializer="glorot_uniform", trainable=True, name="convolution2d_2", bias_constraint=None, kernel_constraint=None, filters=36, bias_regularizer=None, activation="relu", kernel_size=(5, 5), activity_regularizer=None, use_bias=True, data_format="channels_last", padding="valid", kernel_regularizer=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1253: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(strides=[2, 2], kernel_initializer="glorot_uniform", trainable=True, name="convolution2d_3", bias_constraint=None, kernel_constraint=None, filters=48, bias_regularizer=None, activation="relu", kernel_size=(5, 5), activity_regularizer=None, use_bias=True, data_format="channels_last", padding="valid", kernel_regularizer=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1253: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(strides=[1, 1], kernel_initializer="glorot_uniform", trainable=True, name="convolution2d_4", bias_constraint=None, kernel_constraint=None, filters=64, bias_regularizer=None, activation="relu", kernel_size=(3, 3), activity_regularizer=None, use_bias=True, data_format="channels_last", padding="valid", kernel_regularizer=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1253: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(strides=[1, 1], kernel_initializer="glorot_uniform", trainable=True, name="convolution2d_5", bias_constraint=None, kernel_constraint=None, filters=64, bias_regularizer=None, activation="relu", kernel_size=(3, 3), activity_regularizer=None, use_bias=True, data_format="channels_last", padding="valid", kernel_regularizer=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1253: UserWarning: Update your `Dropout` call to the Keras 2 API: `Dropout(name="dropout_1", trainable=True, rate=0.5)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1253: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(kernel_initializer="glorot_uniform", bias_regularizer=None, trainable=True, name="dense_1", activation="relu", use_bias=True, activity_regularizer=None, kernel_constraint=None, units=100, input_dim=6336, kernel_regularizer=None, bias_constraint=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1253: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(kernel_initializer="glorot_uniform", bias_regularizer=None, trainable=True, name="dense_2", activation="relu", use_bias=True, activity_regularizer=None, kernel_constraint=None, units=50, input_dim=100, kernel_regularizer=None, bias_constraint=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1253: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(kernel_initializer="glorot_uniform", bias_regularizer=None, trainable=True, name="dense_3", activation="relu", use_bias=True, activity_regularizer=None, kernel_constraint=None, units=10, input_dim=50, kernel_regularizer=None, bias_constraint=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1253: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(kernel_initializer="glorot_uniform", bias_regularizer=None, trainable=True, name="dense_4", activation="linear", use_bias=True, activity_regularizer=None, kernel_constraint=None, units=1, input_dim=10, kernel_regularizer=None, bias_constraint=None)`
#   return cls(**config)

# %%
m.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 80, 320, 3)        0
# _________________________________________________________________
# convolution2d_1 (Conv2D)     (None, 38, 158, 24)       1824
# _________________________________________________________________
# convolution2d_2 (Conv2D)     (None, 17, 77, 36)        21636
# _________________________________________________________________
# convolution2d_3 (Conv2D)     (None, 7, 37, 48)         43248
# _________________________________________________________________
# convolution2d_4 (Conv2D)     (None, 5, 35, 64)         27712
# _________________________________________________________________
# convolution2d_5 (Conv2D)     (None, 3, 33, 64)         36928
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 33, 64)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6336)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               633700
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 770,619
# Trainable params: 770,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
history= pickle.load( open( "model_history.p", "rb" ) )
loss = history['loss']
valid_loss = history['val_loss']

# %%
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss)
plt.plot(epochs, valid_loss)
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.grid(color='black', linestyle='--', linewidth=1)
plt.show()
