# %%
import pickle
import matplotlib.pyplot as plt
from keras.models import load_model
# Out:
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = load_model('model.h5')
# Out:
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1269: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(kernel_size=(5, 5), activation="relu", trainable=True, strides=[2, 2], data_format="channels_last", kernel_constraint=None, padding="valid", activity_regularizer=None, bias_constraint=None, kernel_initializer="glorot_uniform", kernel_regularizer=None, name="convolution2d_1", use_bias=True, bias_regularizer=None, filters=24)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1269: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(kernel_size=(5, 5), activation="relu", trainable=True, strides=[2, 2], data_format="channels_last", kernel_constraint=None, padding="valid", activity_regularizer=None, bias_constraint=None, kernel_initializer="glorot_uniform", kernel_regularizer=None, name="convolution2d_2", use_bias=True, bias_regularizer=None, filters=36)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1269: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(kernel_size=(5, 5), activation="relu", trainable=True, strides=[2, 2], data_format="channels_last", kernel_constraint=None, padding="valid", activity_regularizer=None, bias_constraint=None, kernel_initializer="glorot_uniform", kernel_regularizer=None, name="convolution2d_3", use_bias=True, bias_regularizer=None, filters=48)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1269: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(kernel_size=(3, 3), activation="relu", trainable=True, strides=[1, 1], data_format="channels_last", kernel_constraint=None, padding="valid", activity_regularizer=None, bias_constraint=None, kernel_initializer="glorot_uniform", kernel_regularizer=None, name="convolution2d_4", use_bias=True, bias_regularizer=None, filters=64)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1269: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(kernel_size=(3, 3), activation="relu", trainable=True, strides=[1, 1], data_format="channels_last", kernel_constraint=None, padding="valid", activity_regularizer=None, bias_constraint=None, kernel_initializer="glorot_uniform", kernel_regularizer=None, name="convolution2d_5", use_bias=True, bias_regularizer=None, filters=64)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1269: UserWarning: Update your `Dropout` call to the Keras 2 API: `Dropout(trainable=True, name="dropout_1", rate=0.5)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1269: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activity_regularizer=None, kernel_initializer="glorot_uniform", kernel_regularizer=None, bias_constraint=None, name="dense_1", activation="relu", trainable=True, bias_regularizer=None, units=100, use_bias=True, input_dim=8448, kernel_constraint=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1269: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activity_regularizer=None, kernel_initializer="glorot_uniform", kernel_regularizer=None, bias_constraint=None, name="dense_2", activation="relu", trainable=True, bias_regularizer=None, units=50, use_bias=True, input_dim=100, kernel_constraint=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1269: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activity_regularizer=None, kernel_initializer="glorot_uniform", kernel_regularizer=None, bias_constraint=None, name="dense_3", activation="relu", trainable=True, bias_regularizer=None, units=10, use_bias=True, input_dim=50, kernel_constraint=None)`
#   return cls(**config)
# /home/demo/anaconda3/envs/py35/lib/python3.5/site-packages/keras/engine/topology.py:1269: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activity_regularizer=None, kernel_initializer="glorot_uniform", kernel_regularizer=None, bias_constraint=None, name="dense_4", activation="linear", trainable=True, bias_regularizer=None, units=1, use_bias=True, input_dim=10, kernel_constraint=None)`
#   return cls(**config)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 160, 320, 3)       0
# _________________________________________________________________
# cropping2d_1 (Cropping2D)    (None, 90, 320, 3)        0
# _________________________________________________________________
# convolution2d_1 (Conv2D)     (None, 43, 158, 24)       1824
# _________________________________________________________________
# convolution2d_2 (Conv2D)     (None, 20, 77, 36)        21636
# _________________________________________________________________
# convolution2d_3 (Conv2D)     (None, 8, 37, 48)         43248
# _________________________________________________________________
# convolution2d_4 (Conv2D)     (None, 6, 35, 64)         27712
# _________________________________________________________________
# convolution2d_5 (Conv2D)     (None, 4, 33, 64)         36928
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 33, 64)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8448)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               844900
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 981,819
# Trainable params: 981,819
# Non-trainable params: 0
# _________________________________________________________________

# %%
history= pickle.load( open( "model_history.p", "rb" ) )
loss = history['loss']
valid_loss = history['val_loss']

# %%
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss)
plt.plot(epochs, valid_loss)
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.grid(color='black', linestyle='--', linewidth=1)
plt.show()
